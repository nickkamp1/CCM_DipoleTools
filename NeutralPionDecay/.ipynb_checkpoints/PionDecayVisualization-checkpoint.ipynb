# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('paper.mplstyle')

from pion_decay import dGamma_dE_rest,dGamma_dE_lab,E_N_rest_bounds,E_N_rest_min,E_N_rest_max,N_HNL
from pion_decay import pi0_width,m_pi0
# Out:
# /home/nwkamp/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
m_N_range = np.linspace(0.01,0.5,5)*m_pi0

for m in m_N_range:
    E_range = np.linspace(E_N_rest_min(m),E_N_rest_max(m),1000)
    dGamma_rest = []
    for E in E_range:
        dGamma_rest.append(dGamma_dE_rest(E,3e-7,m))
    print(sum(np.array(dGamma_rest)[np.array(dGamma_rest)>0])*(E_range[1]-E_range[0]))
    plt.plot(1e3*E_range,dGamma_rest,label=r'$m_\mathcal{N} = %2.1f$ MeV'%(m*1e3))
plt.semilogy()
plt.xlim(0,90)
plt.xlabel(r'$E_\mathcal{N}^{\rm Rest}$ [MeV]')
plt.ylabel(r'$\frac{1}{\Gamma} ~\frac{d \Gamma (\pi^0 \to \mathcal{N}\nu \gamma)}{d E_\mathcal{N}}$')
plt.title(r'$\pi^0$ Rest Frame')
plt.legend()
plt.show()
# Out:
# 6.890309249338433e-17
# 5.683894390905511e-17
# 3.542670942759013e-17
# 1.7018007010739356e-17
# 6.041246397683308e-18

# %%
for gamma in [1.00001,1.1,1.5,2,10]:
    beta = np.sqrt(1-gamma**2)
    for m in m_N_range:
        E_range = np.linspace(gamma*E_N_rest_min(m),gamma*E_N_rest_max(m),100)
        dGamma_lab = []
        for E in E_range:
            dGamma_lab.append(dGamma_dE_lab(E,3e-7,m,gamma))
        plt.plot(1e3*E_range,dGamma_lab,label=r'$m_\mathcal{N} = %2.1f$ MeV'%(m*1e3))
        print(sum(np.array(dGamma_lab)[np.array(dGamma_lab)>0])*(E_range[1]-E_range[0]))
    #plt.xlim(0,135)
    plt.semilogy()
    plt.xlabel(r'$E_\mathcal{N}^{\rm Lab}$ [MeV]')
    plt.ylabel(r'$\frac{1}{\Gamma} ~\frac{d \Gamma (\pi^0 \to \mathcal{N}\nu \gamma)}{d E_\mathcal{N}}$')
    plt.title('Lab Frame')
    plt.legend(title=r'$\gamma = %1.1f$'%gamma)
    plt.show()
# Out:
# <ipython-input-4-a87689c53fa0>:2: RuntimeWarning: invalid value encountered in sqrt
#   beta = np.sqrt(1-gamma**2)
# 6.890639534277117e-17
# 5.682476116433757e-17
# 3.541240375919895e-17
# 1.7009487776020913e-17
# 6.030034167995886e-18
# <ipython-input-4-a87689c53fa0>:2: RuntimeWarning: invalid value encountered in sqrt
#   beta = np.sqrt(1-gamma**2)
# 6.41844840879229e-17
# 5.107564641625697e-17
# 2.9536085968580365e-17
# 1.2049342335774043e-17
# 3.2297728418831615e-18
# <ipython-input-4-a87689c53fa0>:2: RuntimeWarning: invalid value encountered in sqrt
#   beta = np.sqrt(1-gamma**2)
# 5.937769490834644e-17
# 4.309082750380336e-17
# 2.0628720380689514e-17
# 7.53566269348094e-18
# 1.958030656354441e-18
# <ipython-input-4-a87689c53fa0>:2: RuntimeWarning: invalid value encountered in sqrt
#   beta = np.sqrt(1-gamma**2)
# 5.819038997670496e-17
# 3.8220715795121036e-17
# 1.8208653362441792e-17
# 6.6368553358852616e-18
# 1.704926069818054e-18
# <ipython-input-4-a87689c53fa0>:2: RuntimeWarning: invalid value encountered in sqrt
#   beta = np.sqrt(1-gamma**2)
# 5.610883663526616e-17
# 3.414500603145509e-17
# 1.62548641779632e-17
# 5.857120779301026e-18
# 1.49810002036693e-18

# %%
print(N_HNL(0.1,3e-7,0.001))
# Out:
# 3.2840802330387726
# 11.64274053488295
# 21.009148190210915
# 30.4403397855291
# 39.74161847225679
# 47.63774807570485
# 53.70798875287161
# 57.75141971084052
# 60.25601027936652
# 61.70040735932318
# 62.621415570027644
# 63.30805515554986
# 63.78885183822623
# 64.1780882034722
# 64.49489363677536
# 64.80659985235334
# 65.06433202726286
# 65.3070957184632
# 65.48559605820459
# 65.63611713468892
# 65.76733994092935
# 65.85174449811578
# 65.9076733933333
# 65.95005297638392
# 65.97040147537693
# 65.98267946071681
# 65.98737457349796
# 65.99417416583928
# 65.99635246782829
# 65.99635246782829
# 65.99635246782829
